# %%
import torch 
import torchvision 
import numpy as np

import os
import pandas as pd
import albumentations as A
import albumentations.pytorch
import cv2

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
# import torch.nn.functional as F

import sys
sys.path.append('../')
from dataset import val_transforms, CDataset

# %%
import easydict 
args = easydict.EasyDict({ "batch_size": 256, 
                          "epochs": 30, 
                          "data": 0, 
                          'lr':0.1,
                         'momentum':0.9,
                         'weight_decay':1e-4,
                         'start_epoch':0,
                         'gpu':1,
                          'workers':16,
                         'print_freq':2000,
                         'saved_dir':'../trained_models/stain_training_stomach/checkpoint.pt'})

# %%
# make saved dir
from pathlib import Path
path = Path(args.saved_dir.split('checkpoint')[0])
path.mkdir(parents=True, exist_ok=True)

# %%
ngpus_per_node = torch.cuda.device_count()
print(ngpus_per_node)
GPU_NUM = args.gpu # 원하는 GPU 번호 입력
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
print(device)
# Out:
# 3
# cuda:1

# %%
from augment import *

stain_mat = np.array([[ 0.63854984,  0.25636421, -0.05117216],
 [ 0.72885336,  0.89928835,  0.35397438],
 [ 0.24388358,  0.33553481, -0.92226462]])

def HEColor_augment(img, sigma1=0.1, sigma2=1):
    
#     _, StainsFloat, stain_mat  = color_deconvolution_routine(img)
    inv_mat = LA.inv(stain_mat)

#     conversion to Stain & eosin domain
#     od_img = convert_RGB_to_OD(img)
    sda_img = rgb_to_sda(img)
    conv_img = np.matmul(sda_img, inv_mat.T)
    
    '''
        .. [#] Tellez, David, Geert Litjens, Peter Bandi, Wouter Bulten,
               John-Melle Bokhorst, Francesco Ciompi, and Jeroen van der Laak.
               "Quantifying the effects of data augmentation and stain color
               normalization in convolutional neural networks for computational
               pathology." arXiv preprint arXiv:1902.06543 (2019).
    '''
#     only scale for main axis
    for i in range(conv_img.shape[-1]) :
        if i == 2 :
            alpha = np.random.uniform(1 - sigma1, 1 + sigma1)
            conv_img[:,:,i] *= alpha
#         beta = np.random.uniform(-sigma2, sigma2)
        beta = np.random.normal(0, sigma2)            
        conv_img[:,:,i] += beta
        
    aug_img = np.matmul(conv_img, stain_mat.T)
#     aug_img = convert_OD_to_RGB(aug_img)
    aug_img = sda_to_rgb(aug_img)
    
    return np.clip(aug_img, 0, 255)

class HEColorAugment(ImageOnlyTransform) :    
    def __init__(
        self,
        sigma1=0.1,
        sigma2=3.,
        always_apply=False,
        p=1.,
 ):
        super(HEColorAugment, self).__init__(always_apply, p)
        self.sigma1= sigma1
        self.sigma2= sigma2
        
    def apply(self, img,  **params):
        return HEColor_augment(img, self.sigma1, self.sigma2)

# %%
IMAGE_SIZE = 256
from augment import HEColorAugment
train_transforms = A.Compose([
    A.Resize(IMAGE_SIZE, IMAGE_SIZE, p=1),
    A.OneOf([
        A.HorizontalFlip(p=.8),
        A.VerticalFlip(p=.8),
        A.RandomRotate90(p=.8)]
    ),
#     A.RandomResizedCrop(height=IMAGE_SIZE,width=IMAGE_SIZE,scale=[0.95,1.05],ratio=[0.95,1.05],p=0.5),
#     A.transforms.ColorJitter(brightness=0.05, contrast=0.1, saturation=0.1, hue=0.05, p=.8),
    HEColorAugment(sigma1=0.2, sigma2=1., p=0.8),
], p=1.0)

# %%
import albumentations as A
import albumentations.pytorch
import cv2
from augment import HEColorAugment, rgb_to_sda

class CDataset(Dataset):
    def __init__(self, df, defaultpath='/home/beomgon/Dataset/new_patches/', transform=None):
        self.df = df
        self.transform = transform
        self.dir = defaultpath

    def __len__(self):
        return len(self.df)   

    def __getitem__(self, idx):
        path = self.df.iloc[idx, 4]
#         print(pid)

        image = cv2.imread(self.dir + path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = (image.astype(np.float32)-128.)/128.
        
#         if image is uint8, normalization by 255 is done automatically by albumebtation(ToTensor method)
        if self.transform:
            timage = self.transform(image=image)
            image = timage['image']
            
#         image = rgb_to_sda(image)
        
        image =  torch.tensor(image, dtype=torch.float32)/255.
        #image = (torch.tensor(image, dtype=torch.float32)-128)/128
        image = image.permute(2,0,1)
            
        label = self.df.iloc[idx, 5]
        return image, label, path

# %%
train_df = pd.read_csv('../dataframe/train_New_Stomach_df.csv')
train_dataset = CDataset(train_df, defaultpath='/home/beomgon/Dataset/seegene/new_patches/', 
                         transform=train_transforms)

val_df = pd.read_csv('../dataframe/val_New_Stomach_df.csv')
val_dataset = CDataset(val_df, defaultpath='/home/beomgon/Dataset/seegene/new_patches/',
                       transform=val_transforms)  

test_df = pd.read_csv('../dataframe/test_New_Stomach_df.csv')
test_dataset = CDataset(test_df, defaultpath='/home/beomgon/Dataset/seegene/new_patches/',
                        transform=val_transforms)

# %%
image, label, path = next(iter(train_dataset))
# image

# %%
train_loader = DataLoader(train_dataset, batch_size=args.batch_size,
                          shuffle=True, num_workers=args.workers)

val_loader = DataLoader(val_dataset, batch_size=args.batch_size,
                          shuffle=True, num_workers=args.workers)

test_loader = DataLoader(test_dataset, batch_size=args.batch_size,
                          shuffle=True, num_workers=args.workers)

# %%
images, labels, paths = next(iter(train_loader))
images.shape
# Out:
# torch.Size([256, 3, 256, 256])

# %%
import torchvision.models as models
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(512, 3)
model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.Adam(params, lr=0.01, weight_decay=args.weight_decay)
# optimizer = torch.optim.SGD(
#        params, lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay)
# optimizer = torch.optim.SGD(params, lr=args.lr)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[10, 15, 20, 25, 30], 
                                                    gamma=0.2)
# criterion = nn.CrossEntropyLoss(label_smoothing=0.0)
criterion = nn.CrossEntropyLoss().to(device)

# %%
from main import *

# %%
ratio = [0.05, 0.2, 0.4]
acc_list = []
test_acc = []

for num in range(len(ratio)) :
    args.saved_dir = '../trained_models/resnet/stain_1_' + str(num) + '/checkpoint.pt'
    path = Path(args.saved_dir.split('checkpoint')[0])
    path.mkdir(parents=True, exist_ok=True)  
    args.ratio = ratio[num]
    
    train_transforms = A.Compose([
        A.Resize(IMAGE_SIZE, IMAGE_SIZE, p=1),
        A.OneOf([
            A.HorizontalFlip(p=.8),
            A.VerticalFlip(p=.8),
            A.RandomRotate90(p=.8)]
        ),
    #     A.transforms.ColorJitter(brightness=0.05, contrast=0.1, saturation=0.1, hue=0.05, p=.8),
        HEColorAugment(sigma1=args.ratio, sigma2=1., p=0.8),
    ], p=1.0)           
    
    train_df = pd.read_csv('../dataframe/train_New_Stomach_df.csv')
    train_dataset = CDataset(train_df, defaultpath='/home/beomgon/Dataset/seegene/new_patches/', 
                         transform=train_transforms)
    
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size,
                          shuffle=True, num_workers=args.workers)
    
    model = models.resnet18(pretrained=True)
    # model.fc.out_features = 3
    model.fc = nn.Linear(512, 3)
    model.to(device)

    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params, lr=0.01, weight_decay=args.weight_decay)
    # optimizer = torch.optim.SGD(
    #        params, lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[5, 10, 15, 20, 25], 
                                                        gamma=0.2)
    # criterion = nn.CrossEntropyLoss(label_smoothing=0.0)
    criterion = nn.CrossEntropyLoss().to(device)
    
    best_acc1 = 0
    acc1 = 0
    train_loss = []
    val_acc = []

    for epoch in range(args.epochs):
        print('lr', optimizer.param_groups[0]['lr'])
        losses = train(train_loader, model, criterion, optimizer, epoch, args)
        scheduler.step()

        # evaluate after every epoch
        acc1 = validate(val_loader, model, criterion, args)   
        val_acc.append(acc1.item())

        # remember best acc@1 and save checkpoint
        is_best = acc1 > best_acc1
        best_acc1 = max(acc1, best_acc1) 

        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_acc1': best_acc1,
            'optimizer' : optimizer.state_dict(),
            'scheduler' : scheduler.state_dict(),
        }, is_best, filename=args.saved_dir)   
        
    checkpoint = torch.load(args.saved_dir)
    model.load_state_dict(checkpoint['state_dict'])
    acc1 = validate(test_loader, model, criterion, args)    
    print('************* test number {} ratio {} acc{} *************'.format(num, ratio[num], acc1))    
    acc_list.append(val_acc)    
    test_acc.append(acc1)
# Out:
# lr 0.01
# Epoch: [0][  0/297]	Time 24.778 (24.778)	Data 24.057 (24.057)	Loss 1.3956e+00 (1.3956e+00)	Acc@1  24.61 ( 24.61)
# Test: [  0/102]	Time  1.795 ( 1.795)	Loss 1.3781e+00 (1.3781e+00)	Acc@1  51.95 ( 51.95)
#  * Acc@1 48.738
# lr 0.01
# Epoch: [1][  0/297]	Time 22.016 (22.016)	Data 21.753 (21.753)	Loss 7.7262e-01 (7.7262e-01)	Acc@1  70.70 ( 70.70)
# Test: [  0/102]	Time  1.925 ( 1.925)	Loss 1.1007e+00 (1.1007e+00)	Acc@1  60.55 ( 60.55)
#  * Acc@1 62.621
# lr 0.01
# Epoch: [2][  0/297]	Time 18.608 (18.608)	Data 18.344 (18.344)	Loss 5.8350e-01 (5.8350e-01)	Acc@1  73.83 ( 73.83)
# Test: [  0/102]	Time  2.158 ( 2.158)	Loss 1.3490e+00 (1.3490e+00)	Acc@1  58.59 ( 58.59)
#  * Acc@1 55.984
# lr 0.01
# Epoch: [3][  0/297]	Time 18.872 (18.872)	Data 18.615 (18.615)	Loss 4.3042e-01 (4.3042e-01)	Acc@1  83.59 ( 83.59)
# Test: [  0/102]	Time  2.395 ( 2.395)	Loss 2.8567e+00 (2.8567e+00)	Acc@1  42.58 ( 42.58)
#  * Acc@1 41.647
# lr 0.01
# Epoch: [4][  0/297]	Time 21.590 (21.590)	Data 21.306 (21.306)	Loss 4.6023e-01 (4.6023e-01)	Acc@1  83.98 ( 83.98)
# Test: [  0/102]	Time  2.275 ( 2.275)	Loss 9.3894e+00 (9.3894e+00)	Acc@1  34.38 ( 34.38)
#  * Acc@1 34.359
# lr 0.002
# Epoch: [5][  0/297]	Time 19.608 (19.608)	Data 19.346 (19.346)	Loss 3.4635e-01 (3.4635e-01)	Acc@1  85.94 ( 85.94)
# Test: [  0/102]	Time  2.096 ( 2.096)	Loss 2.3922e+00 (2.3922e+00)	Acc@1  57.81 ( 57.81)
#  * Acc@1 55.472
# lr 0.002
# Epoch: [6][  0/297]	Time 17.971 (17.971)	Data 17.707 (17.707)	Loss 3.9480e-01 (3.9480e-01)	Acc@1  88.28 ( 88.28)
# Test: [  0/102]	Time  2.172 ( 2.172)	Loss 2.0225e+00 (2.0225e+00)	Acc@1  58.59 ( 58.59)
#  * Acc@1 54.077
# lr 0.002
# Epoch: [7][  0/297]	Time 19.507 (19.507)	Data 19.251 (19.251)	Loss 2.4748e-01 (2.4748e-01)	Acc@1  89.84 ( 89.84)
# Test: [  0/102]	Time  2.193 ( 2.193)	Loss 2.6890e+00 (2.6890e+00)	Acc@1  44.92 ( 44.92)
#  * Acc@1 46.019
# lr 0.002
# Epoch: [8][  0/297]	Time 18.499 (18.499)	Data 18.236 (18.236)	Loss 2.7652e-01 (2.7652e-01)	Acc@1  89.06 ( 89.06)
# Test: [  0/102]	Time  2.098 ( 2.098)	Loss 1.0491e+01 (1.0491e+01)	Acc@1  38.28 ( 38.28)
#  * Acc@1 35.788
# lr 0.002
# Epoch: [9][  0/297]	Time 17.635 (17.635)	Data 17.373 (17.373)	Loss 2.2034e-01 (2.2034e-01)	Acc@1  91.41 ( 91.41)
# Test: [  0/102]	Time  2.146 ( 2.146)	Loss 3.9030e+00 (3.9030e+00)	Acc@1  56.64 ( 56.64)
#  * Acc@1 53.234
# lr 0.0004
# Epoch: [10][  0/297]	Time 17.994 (17.994)	Data 17.730 (17.730)	Loss 1.9354e-01 (1.9354e-01)	Acc@1  94.14 ( 94.14)
# Test: [  0/102]	Time  2.180 ( 2.180)	Loss 1.5868e+00 (1.5868e+00)	Acc@1  76.56 ( 76.56)
#  * Acc@1 75.502
# lr 0.0004
# Epoch: [11][  0/297]	Time 19.442 (19.442)	Data 19.185 (19.185)	Loss 1.9722e-01 (1.9722e-01)	Acc@1  93.36 ( 93.36)
# Test: [  0/102]	Time  2.229 ( 2.229)	Loss 4.2340e-01 (4.2340e-01)	Acc@1  83.20 ( 83.20)
#  * Acc@1 86.464
# lr 0.0004
# Epoch: [12][  0/297]	Time 18.807 (18.807)	Data 18.544 (18.544)	Loss 1.5519e-01 (1.5519e-01)	Acc@1  92.58 ( 92.58)
# Test: [  0/102]	Time  1.835 ( 1.835)	Loss 7.9003e-01 (7.9003e-01)	Acc@1  81.25 ( 81.25)
#  * Acc@1 78.610
# lr 0.0004
# Epoch: [13][  0/297]	Time 19.600 (19.600)	Data 19.324 (19.324)	Loss 1.9237e-01 (1.9237e-01)	Acc@1  91.41 ( 91.41)
# Test: [  0/102]	Time  2.272 ( 2.272)	Loss 3.8815e-01 (3.8815e-01)	Acc@1  85.55 ( 85.55)
#  * Acc@1 85.655
# lr 0.0004
# Epoch: [14][  0/297]	Time 19.111 (19.111)	Data 18.852 (18.852)	Loss 1.4329e-01 (1.4329e-01)	Acc@1  94.53 ( 94.53)
# Test: [  0/102]	Time  1.906 ( 1.906)	Loss 3.7680e-01 (3.7680e-01)	Acc@1  85.55 ( 85.55)
#  * Acc@1 87.932
# lr 8e-05
# Epoch: [15][  0/297]	Time 20.925 (20.925)	Data 20.644 (20.644)	Loss 1.4453e-01 (1.4453e-01)	Acc@1  94.92 ( 94.92)
# Test: [  0/102]	Time  2.351 ( 2.351)	Loss 3.7376e-01 (3.7376e-01)	Acc@1  87.11 ( 87.11)
#  * Acc@1 88.105
# lr 8e-05
# Epoch: [16][  0/297]	Time 21.176 (21.176)	Data 20.911 (20.911)	Loss 1.3247e-01 (1.3247e-01)	Acc@1  95.31 ( 95.31)
# Test: [  0/102]	Time  2.126 ( 2.126)	Loss 2.6203e-01 (2.6203e-01)	Acc@1  87.50 ( 87.50)
#  * Acc@1 89.615
# lr 8e-05
# Epoch: [17][  0/297]	Time 20.128 (20.128)	Data 19.864 (19.864)	Loss 1.3899e-01 (1.3899e-01)	Acc@1  93.75 ( 93.75)
# Test: [  0/102]	Time  1.958 ( 1.958)	Loss 4.6973e-01 (4.6973e-01)	Acc@1  82.03 ( 82.03)
#  * Acc@1 86.969
# lr 8e-05
# Epoch: [18][  0/297]	Time 19.297 (19.297)	Data 19.034 (19.034)	Loss 1.4025e-01 (1.4025e-01)	Acc@1  94.14 ( 94.14)
# Test: [  0/102]	Time  2.032 ( 2.032)	Loss 2.8033e-01 (2.8033e-01)	Acc@1  89.06 ( 89.06)
#  * Acc@1 88.645
# lr 8e-05
# Epoch: [19][  0/297]	Time 20.096 (20.096)	Data 19.808 (19.808)	Loss 1.1485e-01 (1.1485e-01)	Acc@1  96.88 ( 96.88)
# Test: [  0/102]	Time  2.665 ( 2.665)	Loss 3.7981e-01 (3.7981e-01)	Acc@1  85.94 ( 85.94)
#  * Acc@1 85.174
# lr 1.6000000000000003e-05
# Epoch: [20][  0/297]	Time 19.013 (19.013)	Data 18.754 (18.754)	Loss 1.4098e-01 (1.4098e-01)	Acc@1  94.92 ( 94.92)
# Test: [  0/102]	Time  1.925 ( 1.925)	Loss 3.0013e-01 (3.0013e-01)	Acc@1  89.06 ( 89.06)
#  * Acc@1 89.573
# lr 1.6000000000000003e-05
# Epoch: [21][  0/297]	Time 19.424 (19.424)	Data 19.157 (19.157)	Loss 1.3990e-01 (1.3990e-01)	Acc@1  93.36 ( 93.36)
# Test: [  0/102]	Time  2.147 ( 2.147)	Loss 4.9073e-01 (4.9073e-01)	Acc@1  85.55 ( 85.55)
#  * Acc@1 88.013
# lr 1.6000000000000003e-05
# Epoch: [22][  0/297]	Time 19.959 (19.959)	Data 19.688 (19.688)	Loss 1.0902e-01 (1.0902e-01)	Acc@1  95.70 ( 95.70)
# Test: [  0/102]	Time  1.834 ( 1.834)	Loss 3.1097e-01 (3.1097e-01)	Acc@1  91.41 ( 91.41)
#  * Acc@1 89.215
# lr 1.6000000000000003e-05
# Epoch: [23][  0/297]	Time 16.739 (16.739)	Data 16.464 (16.464)	Loss 1.1100e-01 (1.1100e-01)	Acc@1  95.70 ( 95.70)
# Test: [  0/102]	Time  1.910 ( 1.910)	Loss 2.4071e-01 (2.4071e-01)	Acc@1  89.84 ( 89.84)
#  * Acc@1 90.023
# lr 1.6000000000000003e-05
# Epoch: [24][  0/297]	Time 19.848 (19.848)	Data 19.589 (19.589)	Loss 1.9474e-01 (1.9474e-01)	Acc@1  93.36 ( 93.36)
# Test: [  0/102]	Time  1.977 ( 1.977)	Loss 2.8072e-01 (2.8072e-01)	Acc@1  89.45 ( 89.45)
#  * Acc@1 88.386
# lr 3.2000000000000007e-06
# Epoch: [25][  0/297]	Time 17.223 (17.223)	Data 16.955 (16.955)	Loss 1.5184e-01 (1.5184e-01)	Acc@1  94.53 ( 94.53)
# Test: [  0/102]	Time  1.928 ( 1.928)	Loss 2.8067e-01 (2.8067e-01)	Acc@1  90.23 ( 90.23)
#  * Acc@1 89.615
# lr 3.2000000000000007e-06
# Epoch: [26][  0/297]	Time 19.361 (19.361)	Data 19.093 (19.093)	Loss 1.3108e-01 (1.3108e-01)	Acc@1  95.31 ( 95.31)
# Test: [  0/102]	Time  1.780 ( 1.780)	Loss 2.2845e-01 (2.2845e-01)	Acc@1  90.62 ( 90.62)
#  * Acc@1 88.706
# lr 3.2000000000000007e-06
# Epoch: [27][  0/297]	Time 19.637 (19.637)	Data 19.383 (19.383)	Loss 1.1501e-01 (1.1501e-01)	Acc@1  96.09 ( 96.09)
# Test: [  0/102]	Time  2.093 ( 2.093)	Loss 2.7795e-01 (2.7795e-01)	Acc@1  89.45 ( 89.45)
#  * Acc@1 90.016
# lr 3.2000000000000007e-06
# Epoch: [28][  0/297]	Time 19.927 (19.927)	Data 19.663 (19.663)	Loss 9.2691e-02 (9.2691e-02)	Acc@1  97.27 ( 97.27)
# Test: [  0/102]	Time  2.173 ( 2.173)	Loss 2.7393e-01 (2.7393e-01)	Acc@1  88.28 ( 88.28)
#  * Acc@1 86.892
# lr 3.2000000000000007e-06
# Epoch: [29][  0/297]	Time 18.687 (18.687)	Data 18.420 (18.420)	Loss 1.6627e-01 (1.6627e-01)	Acc@1  92.19 ( 92.19)
# Test: [  0/102]	Time  1.825 ( 1.825)	Loss 2.5247e-01 (2.5247e-01)	Acc@1  90.23 ( 90.23)
#  * Acc@1 89.958
# Test: [ 0/60]	Time  2.121 ( 2.121)	Loss 2.4805e-01 (2.4805e-01)	Acc@1  92.58 ( 92.58)
#  * Acc@1 91.104
# ************* test number 0 ratio 0.05 acc91.1039047241211 *************
# lr 0.01
# Epoch: [0][  0/297]	Time 21.466 (21.466)	Data 21.180 (21.180)	Loss 1.1625e+00 (1.1625e+00)	Acc@1  38.28 ( 38.28)
# Test: [  0/102]	Time  2.401 ( 2.401)	Loss 5.1654e+01 (5.1654e+01)	Acc@1  23.83 ( 23.83)
#  * Acc@1 26.370
# lr 0.01
# Epoch: [1][  0/297]	Time 19.641 (19.641)	Data 19.385 (19.385)	Loss 6.7866e-01 (6.7866e-01)	Acc@1  72.66 ( 72.66)
# Test: [  0/102]	Time  2.002 ( 2.002)	Loss 2.8510e+00 (2.8510e+00)	Acc@1  45.70 ( 45.70)
#  * Acc@1 46.839
# lr 0.01
# Epoch: [2][  0/297]	Time 18.608 (18.608)	Data 18.341 (18.341)	Loss 3.9021e-01 (3.9021e-01)	Acc@1  85.94 ( 85.94)
# Test: [  0/102]	Time  1.812 ( 1.812)	Loss 1.8435e+00 (1.8435e+00)	Acc@1  48.44 ( 48.44)
#  * Acc@1 43.473
# lr 0.01
# Epoch: [3][  0/297]	Time 16.372 (16.372)	Data 16.106 (16.106)	Loss 4.7165e-01 (4.7165e-01)	Acc@1  80.86 ( 80.86)
# Test: [  0/102]	Time  1.966 ( 1.966)	Loss 1.2964e+00 (1.2964e+00)	Acc@1  53.91 ( 53.91)
#  * Acc@1 51.635
# lr 0.01
# Epoch: [4][  0/297]	Time 16.820 (16.820)	Data 16.527 (16.527)	Loss 7.1151e-01 (7.1151e-01)	Acc@1  73.83 ( 73.83)
# Test: [  0/102]	Time  1.868 ( 1.868)	Loss 9.3368e+00 (9.3368e+00)	Acc@1  28.91 ( 28.91)
#  * Acc@1 34.248
# lr 0.002
# Epoch: [5][  0/297]	Time 17.967 (17.967)	Data 17.704 (17.704)	Loss 3.2552e-01 (3.2552e-01)	Acc@1  89.84 ( 89.84)
# Test: [  0/102]	Time  1.933 ( 1.933)	Loss 9.8772e-01 (9.8772e-01)	Acc@1  65.62 ( 65.62)
#  * Acc@1 66.284
# lr 0.002
# Epoch: [6][  0/297]	Time 16.485 (16.485)	Data 16.227 (16.227)	Loss 2.8420e-01 (2.8420e-01)	Acc@1  89.45 ( 89.45)
# Test: [  0/102]	Time  1.865 ( 1.865)	Loss 8.2165e-01 (8.2165e-01)	Acc@1  67.97 ( 67.97)
#  * Acc@1 70.263
# lr 0.002
# Epoch: [7][  0/297]	Time 16.080 (16.080)	Data 15.798 (15.798)	Loss 2.3988e-01 (2.3988e-01)	Acc@1  91.02 ( 91.02)
# Test: [  0/102]	Time  1.824 ( 1.824)	Loss 8.6824e-01 (8.6824e-01)	Acc@1  70.70 ( 70.70)
#  * Acc@1 74.893
# lr 0.002
# Epoch: [8][  0/297]	Time 15.861 (15.861)	Data 15.593 (15.593)	Loss 2.6105e-01 (2.6105e-01)	Acc@1  89.06 ( 89.06)
# Test: [  0/102]	Time  2.246 ( 2.246)	Loss 1.7746e+00 (1.7746e+00)	Acc@1  66.02 ( 66.02)
#  * Acc@1 68.926
# lr 0.002
# Epoch: [9][  0/297]	Time 17.516 (17.516)	Data 17.256 (17.256)	Loss 2.2872e-01 (2.2872e-01)	Acc@1  92.19 ( 92.19)
# Test: [  0/102]	Time  2.184 ( 2.184)	Loss 6.9447e+00 (6.9447e+00)	Acc@1  58.98 ( 58.98)
#  * Acc@1 62.609
# lr 0.0004
# Epoch: [10][  0/297]	Time 17.765 (17.765)	Data 17.474 (17.474)	Loss 1.4937e-01 (1.4937e-01)	Acc@1  94.92 ( 94.92)
# Test: [  0/102]	Time  1.816 ( 1.816)	Loss 6.0769e-01 (6.0769e-01)	Acc@1  81.25 ( 81.25)
#  * Acc@1 82.127
# lr 0.0004
# Epoch: [11][  0/297]	Time 18.644 (18.644)	Data 18.379 (18.379)	Loss 2.3941e-01 (2.3941e-01)	Acc@1  91.80 ( 91.80)
# Test: [  0/102]	Time  1.999 ( 1.999)	Loss 6.5450e+00 (6.5450e+00)	Acc@1  56.64 ( 56.64)
#  * Acc@1 58.492
# lr 0.0004
# Epoch: [12][  0/297]	Time 16.951 (16.951)	Data 16.674 (16.674)	Loss 1.9734e-01 (1.9734e-01)	Acc@1  91.41 ( 91.41)
# Test: [  0/102]	Time  2.102 ( 2.102)	Loss 4.1171e-01 (4.1171e-01)	Acc@1  84.38 ( 84.38)
#  * Acc@1 85.093
# lr 0.0004
# Epoch: [13][  0/297]	Time 18.327 (18.327)	Data 18.062 (18.062)	Loss 1.3453e-01 (1.3453e-01)	Acc@1  96.09 ( 96.09)
# Test: [  0/102]	Time  2.070 ( 2.070)	Loss 4.1249e-01 (4.1249e-01)	Acc@1  83.98 ( 83.98)
#  * Acc@1 84.658
# lr 0.0004
# Epoch: [14][  0/297]	Time 16.294 (16.294)	Data 16.022 (16.022)	Loss 1.7881e-01 (1.7881e-01)	Acc@1  93.75 ( 93.75)
# Test: [  0/102]	Time  1.853 ( 1.853)	Loss 2.9503e+00 (2.9503e+00)	Acc@1  77.73 ( 77.73)
#  * Acc@1 75.644
# lr 8e-05
# Epoch: [15][  0/297]	Time 15.846 (15.846)	Data 15.586 (15.586)	Loss 1.6067e-01 (1.6067e-01)	Acc@1  94.53 ( 94.53)
# Test: [  0/102]	Time  1.951 ( 1.951)	Loss 3.1204e-01 (3.1204e-01)	Acc@1  90.62 ( 90.62)
#  * Acc@1 87.535
# lr 8e-05
# Epoch: [16][  0/297]	Time 18.421 (18.421)	Data 18.140 (18.140)	Loss 1.2688e-01 (1.2688e-01)	Acc@1  96.48 ( 96.48)
# Test: [  0/102]	Time  1.824 ( 1.824)	Loss 3.2081e-01 (3.2081e-01)	Acc@1  88.67 ( 88.67)
#  * Acc@1 88.537
# lr 8e-05
# Epoch: [17][  0/297]	Time 17.748 (17.748)	Data 17.485 (17.485)	Loss 1.3052e-01 (1.3052e-01)	Acc@1  94.14 ( 94.14)
# Test: [  0/102]	Time  1.863 ( 1.863)	Loss 3.3027e-01 (3.3027e-01)	Acc@1  90.62 ( 90.62)
#  * Acc@1 87.038
# lr 8e-05
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4152/4160359673.py", line 50, in <module>
#     losses = train(train_loader, model, criterion, optimizer, epoch, args)
#   File "/home/beomgon/project/seegene/stain_training/../main.py", line 37, in train
#     for i, (images, targets, _) in enumerate(train_loader):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 521, in __next__
#     data = self._next_data()
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1186, in _next_data
#     idx, data = self._get_data()
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1152, in _get_data
#     success, data = self._try_get_data()
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 990, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/queues.py", line 107, in get
#     if not self._poll(timeout):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py", line 424, in _poll
#     r = wait([self], timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 702, in getsourcefile
#     elif any(filename.endswith(s) for s in
#   File "/home/beomgon/anaconda3/envs/pytorch/lib/python3.8/inspect.py", line 702, in <genexpr>
#     elif any(filename.endswith(s) for s in
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_4152/4160359673.py in <module>
#      49         print('lr', optimizer.param_groups[0]['lr'])
# ---> 50         losses = train(train_loader, model, criterion, optimizer, epoch, args)
#      51         scheduler.step()
#
# ~/project/seegene/stain_training/../main.py in train(train_loader, model, criterion, optimizer, epoch, args)
#      36     end = time.time()
# ---> 37     for i, (images, targets, _) in enumerate(train_loader):
#      38         # measure data loading time
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#
# ~/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/queues.py in get(self, block, timeout)
#     106                     timeout = deadline - time.monotonic()
# --> 107                     if not self._poll(timeout):
#     108                         raise Empty
#
# ~/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py in poll(self, timeout)
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#
# ~/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py in _poll(self, timeout)
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#
# ~/anaconda3/envs/pytorch/lib/python3.8/multiprocessing/connection.py in wait(object_list, timeout)
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#
# ~/anaconda3/envs/pytorch/lib/python3.8/selectors.py in select(self, timeout)
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

epochs = range(args.epochs)
plt.rcParams["figure.figsize"] = (10,8)
plt.rcParams['lines.linewidth'] = 1
plt.plot(epochs, acc_list[0], linestyle='--')
plt.plot(epochs, acc_list[1])
plt.plot(epochs, acc_list[2])
plt.legend(['0.05', '0.2', '0.4'])
plt.xlabel('epochs')
plt.ylabel('val acc')
plt.title('val acc with different sigma using resnet18 for colon')
# plt.axis([10, 30, 88, 94])
plt.show()
print(test_acc)
