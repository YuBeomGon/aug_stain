# %%
# %matplotlib inline
import numpy as np
import openslide
import cv2
import matplotlib.pyplot as plt
import sys
# sys.path.append('../dataset')

# %%
mrxs_path = "../test/train_stomach_D_0001.mrxs"
slide = openslide.OpenSlide(mrxs_path)

# %%
type(slide)
# Out:
# openslide.OpenSlide

# %%
# !pwd
# Out:
# /home/beomgon/pytorch/seegene/notebooks

# %%
slide.get_thumbnail((1000, 1000))
# Out:
# <PIL.Image.Image image mode=RGB size=444x1000 at 0x2BA9DA3A6D60>

# %%
slide.level_dimensions
# Out:
# ((90112, 205312),
#  (45056, 102656),
#  (22528, 51328),
#  (11264, 25664),
#  (5632, 12832),
#  (2816, 6416),
#  (1408, 3208),
#  (704, 1604),
#  (352, 802),
#  (176, 401))

# %%
mrxs_path = "../data/train_data/Colon/D/train_colon_D_0001.mrxs"
slide = openslide.OpenSlide(mrxs_path)

h, w = slide.level_dimensions[0]
print("Original WSI shape: ({}, {})".format(h, w))
# Out:
# Original WSI shape: (90112, 205312)

# %%
mrxs_path = "../data/train_data/Colon/D/train_colon_D_0001.mrxs"
slide = openslide.OpenSlide(mrxs_path)

h, w = slide.level_dimensions[0]
print("Original WSI shape: ({}, {})".format(h, w))
# Out:
# Original WSI shape: (90112, 205312)

# %%
patch = slide.read_region((0, 0), 5, (2816, 6360))

# %%
np.array(patch).shape
# Out:
# (6360, 2816, 4)

# %%
patch
# Out:
# <PIL.Image.Image image mode=RGBA size=2816x6360 at 0x2B11BE134730>

# %%
arr = np.array(patch)[:, :, 0:3]
plt.figure(figsize=(10,10))
plt.imshow(arr)

# %%
arr.
